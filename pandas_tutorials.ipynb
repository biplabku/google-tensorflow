# %%
import pandas as pd
print(pd.__version__)
print("completed")
# Out:
# 0.22.0
# completed

# %%
names = ['bob','tim','cla','po']
days = [1,2,3,4]
nData = list(zip(names, days))
print (nData)
# Out:
# [('bob', 1), ('tim', 2), ('cla', 3), ('po', 4)]

# %%
df1 = pd.DataFrame(data = nData, columns=['Names', 'Birthdates'])
print(df1)
# Out:
#   Names  Birthdates
# 0   bob           1
# 1   tim           2
# 2   cla           3
# 3    po           4

# %%
path = r'/Users/biplabkumardas/google-tensorflow/california_housing_train.csv'
df = pd.read_csv(path)
print(df)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -114.31     34.19                15.0       5612.0          1283.0
# 1        -114.47     34.40                19.0       7650.0          1901.0
# 2        -114.56     33.69                17.0        720.0           174.0
# 3        -114.57     33.64                14.0       1501.0           337.0
# 4        -114.57     33.57                20.0       1454.0           326.0
# 5        -114.58     33.63                29.0       1387.0           236.0
# 6        -114.58     33.61                25.0       2907.0           680.0
# 7        -114.59     34.83                41.0        812.0           168.0
# 8        -114.59     33.61                34.0       4789.0          1175.0
# 9        -114.60     34.83                46.0       1497.0           309.0
# 10       -114.60     33.62                16.0       3741.0           801.0
# ...

# %%
# what if we do not pass header 
path = r'/Users/biplabkumardas/google-tensorflow/california_housing_train.csv'
df = pd.read_csv(path, header = None)
print(df)
# Out:
#                  0          1                   2            3  \
# 0        longitude   latitude  housing_median_age  total_rooms
# 1      -114.310000  34.190000           15.000000  5612.000000
# 2      -114.470000  34.400000           19.000000  7650.000000
# 3      -114.560000  33.690000           17.000000   720.000000
# 4      -114.570000  33.640000           14.000000  1501.000000
# 5      -114.570000  33.570000           20.000000  1454.000000
# 6      -114.580000  33.630000           29.000000  1387.000000
# 7      -114.580000  33.610000           25.000000  2907.000000
# 8      -114.590000  34.830000           41.000000   812.000000
# 9      -114.590000  33.610000           34.000000  4789.000000
# 10     -114.600000  34.830000           46.000000  1497.000000
# 11     -114.600000  33.620000           16.000000  3741.000000
# 12     -114.600000  33.600000           21.000000  1988.000000
# 13     -114.610000  34.840000           48.000000  1291.000000
# ...

# %%
# for removing the csv file
import os 
# os.remove(path)

# %%
# checking the datatypes of the variables in the columns
df1.dtypes
df1.Birthdates.dtype
# Out:
# dtype('int64')
